# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np

def gred(x,y):
    wc=bc=0
    it = 1000
    n = len(x)
    lr = 0.0001
    for i in range(it):
        yp = wc*x + bc
        cost = (1/n) * sum([val**2 for val in (y-yp)])
        
        wd = (2/n)*sum(x*(y-yp))
        bd = (2/n)*sum(y-yp)
        wc = wc - lr*wd
        bc = bc - lr*bd
        print ("m-{}, b-{}, cost-{}, it-{}".format(wc,bc,cost,i))        
        
x = np.array([1,2,3,4,5])
y = np.array([5,7,8,11,13])

gred(x,y)
# Out:
# m--0.00608, b--0.0017600000000000003, cost-85.60000000000001, it-0
# m--0.012174432, b--0.0035240000000000002, cost-86.0011139328, it-1
# m--0.018283330150400002, b--0.0052920094592, cost-86.40412808510597, it-2
# m--0.0244067286824064, b--0.00706403785918208, cost-86.80905146010224, it-3
# m--0.030544661908223206, b--0.008840094703963361, cost-87.21589310363014, it-4
# m--0.036697164221243674, b--0.010620189520049087, cost-87.62466210438988, it-5
# m--0.04286427009624244, b--0.012404331856485843, cost-88.03536759414389, it-6
# m--0.04904601408956807, b--0.014192531284914886, cost-88.44801874792057, it-7
# m--0.05524243083933607, b--0.01598479739962561, cost-88.86262478421953, it-8
# m--0.06145355506562238, b--0.017781139817609135, cost-89.27919496521736, it-9
# m--0.06767942157065732, b--0.01958156817861203, cost-89.69773859697469, it-10
# m--0.07392006523901994, b--0.021386092145190147, cost-90.11826502964405, it-11
# ...

# %%
gred(x,y)
# Out:
# m--0.00608, b--0.0017600000000000003, cost-85.60000000000001, it-0
# m--0.012174432, b--0.0035240000000000002, cost-86.0011139328, it-1
# m--0.018283330150400002, b--0.0052920094592, cost-86.40412808510597, it-2
# m--0.0244067286824064, b--0.00706403785918208, cost-86.80905146010224, it-3
# m--0.030544661908223206, b--0.008840094703963361, cost-87.21589310363014, it-4
# m--0.036697164221243674, b--0.010620189520049087, cost-87.62466210438988, it-5
# m--0.04286427009624244, b--0.012404331856485843, cost-88.03536759414389, it-6
# m--0.04904601408956807, b--0.014192531284914886, cost-88.44801874792057, it-7
# m--0.05524243083933607, b--0.01598479739962561, cost-88.86262478421953, it-8
# m--0.06145355506562238, b--0.017781139817609135, cost-89.27919496521736, it-9
# m--0.06767942157065732, b--0.01958156817861203, cost-89.69773859697469, it-10
# m--0.07392006523901994, b--0.021386092145190147, cost-90.11826502964405, it-11
# ...
